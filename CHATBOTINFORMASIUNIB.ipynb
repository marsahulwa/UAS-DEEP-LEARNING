# %%
import json

data = {

  "intents": [
    {
      "tag": "greeting",
      "patterns": [
        "hallo", "hai", "halo", "selamat pagi", "pagi",
        "siang", "sore", "malam", "selamat siang",
        "selamat sore", "selamat malam"
      ],
      "responses": [
        "Hai! SahabatUnib di sini. Mau tau informasi tentang apa nih?",
        "Halo! Saya SahabatUnib, salam kenal ya! Mau tau tentang Universitas Bengkulu?"
      ]
    },
    {
      "tag": "SahabatUnib",
      "patterns": [
        "Apa itu SahabatUnib", "SahabatUnib itu apa?", "SahabatUnib"
      ],
      "responses": [
        "SahabatUnib adalah chatbot informasi tentang Universitas Bengkulu!",
        "SahabatUnib adalah teman informasi tentang Universitas Bengkulu!"
      ]
    },
    {
      "tag": "sejarah_universitas_bengkulu",
      "patterns": [
        "Ceritakan sejarah Universitas Bengkulu",
        "Apa sejarah UNIB?",
        "Bagaimana sejarah berdirinya Universitas Bengkulu?"
      ],
      "responses": [
        "Universitas Bengkulu (UNIB) didirikan berdasarkan Keputusan Presiden RI Nomor 17 Tahun 1982 dan diresmikan oleh Menteri Pendidikan dan Kebudayaan Republik Indonesia, Prof. Dr. Daud Yusuf. Rektor pertama UNIB adalah Prof. Ir. Soenjoto Sumodihardjo (UGM), yang menjabat dari 1982 hingga 1986. Pendirian UNIB merupakan hasil perjuangan Gubernur Soeprapto bersama masyarakat dan tokoh adat Bengkulu, dengan dukungan perguruan tinggi swasta Universitas Semarak Bengkulu (UNSEB)."
      ]
    },
    {
      "tag": "rektor_universitas_bengkulu",
      "patterns": [
        "Siapa saja rektor UNIB?",
        "Daftar rektor Universitas Bengkulu?",
        "Rektor UNIB dari dulu sampai sekarang siapa saja?"
      ],
      "responses": [
        "Berikut adalah daftar rektor Universitas Bengkulu: \n1. Prof. Ir. Soenjoto Sumodihardjo (1982–1986)\n2. Dr. Ir. Soekotjo (1986–1990)\n3. Dr. Ir. Nitza Arbi (1990–1995)\n4. Prof. Dr. H Zulkifli Husin, S.E., M.Sc. (1995–2005)\n5. Prof. Ir. Zainal Muktamar, M.Sc., Ph.D. (2005–2013)\n6. Dr. Ridwan Nurazi, S.E., M.Sc., Ak. (2013–2021)\n7. Dr. Retno Agustina Ekaputri, S.E., M.Sc. (2021–sekarang)."
      ]
    },
    {
      "tag": "visi_misi_universitas_bengkulu",
      "patterns": [
        "Apa visi Universitas Bengkulu?",
        "Apa misi UNIB?",
        "Visi dan misi Universitas Bengkulu?"
      ],
      "responses": [
        "Visi Universitas Bengkulu adalah 'Menjadi universitas unggul, berbudaya, dan berdaya saing internasional.'\nMisi: \n1. Menciptakan sistem tata kelola yang profesional, tangguh, adil, dan berkelanjutan.\n2. Mengembangkan sistem pendidikan yang dapat diakses oleh semua lapisan masyarakat.\n3. Melaksanakan penelitian dan pengabdian kepada masyarakat secara lokal, nasional, dan internasional.\n4. Mengintegrasikan kegiatan Tridharma untuk pengembangan ilmu pengetahuan dan ketahanan negara."
      ]
    },
    {
      "tag": "fungsi_universitas_bengkulu",
      "patterns": [
        "Apa fungsi Universitas Bengkulu?",
        "Apa peran UNIB dalam pendidikan?"
      ],
      "responses": [
        "Fungsi Universitas Bengkulu:\n1. Mengembangkan pendidikan tinggi.\n2. Melaksanakan penelitian untuk pengembangan ilmu pengetahuan, teknologi, seni, dan olahraga.\n3. Melaksanakan pengabdian kepada masyarakat.\n4. Melaksanakan pembinaan sivitas akademika dan hubungan dengan lingkungan.\n5. Memberikan pelayanan administrasi yang profesional."
      ]
    },
    {
      "tag": "tujuan_universitas_bengkulu",
      "patterns": [
        "Apa tujuan Universitas Bengkulu?",
        "Apa tujuan dari UNIB?"
      ],
      "responses": [
        "Tujuan Universitas Bengkulu adalah:\n1. Menghasilkan lulusan berkualitas, profesional, dan berkarakter global.\n2. Mengembangkan ilmu pengetahuan dan teknologi ramah lingkungan melalui riset.\n3. Meningkatkan kualitas pelayanan, kemandirian penganggaran, dan transparansi."
      ]
    },
    {
        "tag": "fakultas_universitas_bengkulu",
        "patterns": [
            "Apa saja fakultas di Universitas Bengkulu?",
            "Fakultas di UNIB apa saja?",
            "Daftar fakultas di Universitas Bengkulu?"
        ],
        "responses": [
            "Berikut adalah fakultas yang ada di Universitas Bengkulu:\n1. Fakultas Keguruan dan Ilmu Pendidikan (FKIP) - laman web: https://www.unib.ac.id/fakultas/fakultas-keguruan-dan-ilmpu-pendidikan/\n2. Fakultas Hukum (FH) - laman web: https://www.unib.ac.id/fakultas/fakultas-hukum/\n3. Fakultas Ekonomi dan Bisnis (FEB) - laman web: https://www.unib.ac.id/fakultas/economis-and-business/\n4. Fakultas Ilmu Sosial dan Ilmu Politik (FISIP) - laman web: https://www.unib.ac.id/fakultas/fakultas-ilmu-sosial-dan-ilmu-politik/\n5. Fakultas Pertanian (FP) - laman web: https://www.unib.ac.id/fakultas/fakultas-pertanina/\n6. Fakultas Matematika dan Ilmu Pengetahuan Alam (FMIPA) - laman web: https://www.unib.ac.id/fakultas/fakultas-matematika-dan-ilmu-pengetahuan-alam/\n7. Fakultas Teknik (FT) - laman web: https://www.unib.ac.id/fakultas/fakultas-teknik/\n8. Fakultas Kedokteran dan Ilmu Kesehatan (FKIK) - laman web: https://www.unib.ac.id/fakultas/fakultas-kedokteran/"
        ]
    },
    {
        "tag": "struktur_organisasi_universitas_bengkulu",
        "patterns": [
            "Bagaimana struktur organisasi Universitas Bengkulu?",
            "Siapa pimpinan di Universitas Bengkulu?",
            "Struktur organisasi di UNIB?"
        ],
        "responses": [
            "Struktur organisasi Universitas Bengkulu:\nPimpinan Utama:\n- Rektor: Dr. Retno Agustina Ekaputri, S.E., M.Sc.\n- Wakil Rektor Bidang Akademik: Prof. Dr. Mochamad Lutfi Firdaus, S.Si, M.T.\n- Wakil Rektor Bidang Sumber Daya: Yefriza, S.E., MPPM, Ph.D.\n- Wakil Rektor Bidang Kemahasiswaan: Prof. Dr. Candra Irawan, S.H., M.Hum.\n- Wakil Rektor Bidang Perencanaan dan Kerja Sama: Prof. Dr. Irfan Gustian, S.Si, M.Si."
        ]
    },
    {
        "tag": "unit_pendukung_universitas_bengkulu",
        "patterns": [
            "Apa saja unit pendukung di Universitas Bengkulu?",
            "Unit pendukung UNIB?",
            "Apa unit yang mendukung di Universitas Bengkulu?"
        ],
        "responses": [
            "Beberapa unit pendukung di Universitas Bengkulu:\n1. Lembaga Penelitian dan Pengabdian kepada Masyarakat (LPPM) - Ketua: Dr. Ir. Hery Suhartoyo, M.Sc.\n2. Rektorat (Biro Umum dan Sumber Daya) - PLT Kepala Biro: Drs. Jalaludin.\n3. Rektorat (Biro Perencanaan, Pembelajaran, dan Kemahasiswaan) - PLT Kepala Biro: Drs. M. Mirhasudin, M.Si."
        ]
    },
    {
        "tag": "biro_universitas_bengkulu",
        "patterns": [
            "Apa saja biro yang ada di Universitas Bengkulu?",
            "Sebutkan biro di UNIB.",
            "Biro apa saja yang ada di UNIB?"
        ],
        "responses": [
            "Berikut adalah daftar biro di Universitas Bengkulu:\n1. Biro Perencanaan dan Pengembangan (Biro PPK).\n2. Biro Umum dan Sumber Daya (Biro USD)."
        ]
    },
    {
        "tag": "lembaga_universitas_bengkulu",
        "patterns": [
            "Apa saja lembaga di Universitas Bengkulu?",
            "Sebutkan lembaga di UNIB.",
            "Lembaga apa saja yang ada di UNIB?"
        ],
        "responses": [
            "Berikut adalah daftar lembaga di Universitas Bengkulu:\n1. Lembaga Penelitian dan Pengabdian kepada Masyarakat (LPPM).\n2. Lembaga Pengembangan Teknologi Informasi dan Komunikasi (LPTIK).\n3. Lembaga Pengembangan Mutu Pendidikan dan Penjaminan Mutu (LPMPP)."
        ]
    },
    {
        "tag": "upt_universitas_bengkulu",
        "patterns": [
            "Apa saja UPT yang ada di Universitas Bengkulu?",
            "Sebutkan UPT di UNIB.",
            "UPT apa saja di UNIB?"
        ],
        "responses": [
            "Berikut adalah daftar UPT di Universitas Bengkulu:\n1. UPT Perpustakaan.\n2. UPT Kearsipan.\n3. UPT Kerja Sama dan Layanan Internasional.\n4. UPT Bahasa."
        ]
    },
    {
        "tag": "undang_undang_pendidikan_tinggi",
        "patterns": [
            "Apa saja undang-undang yang terkait dengan pendidikan tinggi?",
            "Sebutkan peraturan mengenai pendidikan tinggi di Indonesia.",
            "Apa saja peraturan yang berlaku untuk pendidikan tinggi?"
        ],
        "responses": [
            "Berikut adalah kumpulan perundang-undangan di Indonesia yang berkaitan dengan dunia pendidikan tinggi:\n1. Undang-Undang Republik Indonesia - laman web: https://www.unib.ac.id/pusat-informasi/peraturan-peraturan/peraturan_uu/\n2. Peraturan Pemerintah - laman web: https://www.unib.ac.id/pusat-informasi/peraturan-peraturan/peraturan_pp/\n3. Peraturan Presiden dan Keputusan Presiden - laman web: https://www.unib.ac.id/pusat-informasi/peraturan-peraturan/peraturan_perpres/\n4. Peraturan dan Keputusan Menteri - laman web: https://www.unib.ac.id/pusat-informasi/peraturan-peraturan/peraturan_kepmen/\n5. Peraturan dan Keputusan Direktorat Jenderal dan Sekretaris Jenderal - laman web: https://www.unib.ac.id/pusat-informasi/peraturan-peraturan/peraturan_dirjen/\n6. Peraturan dan Keputusan Rektor Universitas Bengkulu - laman web: https://www.unib.ac.id/pusat-informasi/peraturan-peraturan/peraturan_rektorat/\n7. Peraturan dan Keputusan lainnya - laman web: https://www.unib.ac.id/pusat-informasi/peraturan-peraturan/peraturankeputusan-lainnya/\n8. Surat Edaran - laman web: https://www.unib.ac.id/pusat-informasi/peraturan-peraturan/surat-edaran/"
        ]
    },
    {
        "tag": "berita_utama",
        "patterns": [
            "Apa berita terbaru di Universitas Bengkulu?",
            "Berita apa saja yang ada di UNIB?",
            "Ceritakan berita utama dari Universitas Bengkulu."
        ],
        "responses": [
            "Berikut adalah berita utama dari Universitas Bengkulu:\n1. Unib Raih Predikat Informatif Anugerah Keterbukaan Informasi Publik 2024 - laman web: https://www.unib.ac.id/unib-raih-predikat-informatif-anugerah-keterbukaan-informasi-publik-2024/\n2. Dosen Unib Juara II Kompetisi Hibah Pengembangan Pembelajaran Bagi Penyandang Disabilitas - laman web: https://www.unib.ac.id/dosen-unib-juara-ii-kompetisi-hibah-pengembangan-pembelajaran-bagi-penyandang-disabilitas/"
        ]
    },
    {
        "tag": "hubungi_kami",
        "patterns": [
            "Bagaimana cara menghubungi Universitas Bengkulu?",
            "Alamat Universitas Bengkulu?",
            "Nomor telepon Universitas Bengkulu?",
            "Media sosial Universitas Bengkulu?"
        ],
        "responses": [
            "Berikut adalah informasi kontak Universitas Bengkulu:\n\nKampus Utama:\n- Jl. W.R Supratman\n- Kandang Limun\n- Bengkulu 38122\n- Sumatera – INDONESIA\n\nKampus II (PGSD Universitas Bengkulu):\n- Jalan Cimanuk, Jl. Gedang, Kec. Gading Cemp., Kota Bengkulu, Bengkulu 38225\n\nKampus III (Penjaskes FKIP):\n- Jl. Raden Fatah No.3, Pagar Dewa, Kec. Selebar, Kota Bengkulu, Bengkulu 38211\n\nKampus IV:\n- Jl. Indragiri, Padang Harapan, Kec. Gading Cemp., Kota Bengkulu, Bengkulu 38225\n\nKontak:\n- Tel: +62 736 21170 dan 21884\n- Fax: +62 736 22105\n- E-mail: rektorat@unib.ac.id\n\nMedia Sosial Universitas Bengkulu:\n- Instagram (UNIB): UNIB Official\n- Twitter (UNIB): Universitas Bengkulu\n- YouTube (UNIB): Universitas Bengkulu\n\nMedia Sosial PPID Universitas Bengkulu:\n- Facebook (PPID): University of Bengkulu\n- Instagram (PPID): PPID Universitas Bengkulu\n- Twitter (PPID): PPID Universitas Bengkulu\n- YouTube (PPID): PPID Universitas Bengkulu"
        ]
    },
    {
      "tag": "panduan_akademik",
      "patterns": [
        "Panduan akademik",
        "Panduan akademik terbaru"
        "Panduan akademik tahun 2024 Universitas Bengkulu"
       ],
      "responses": [
        "Berikut adalah informasi Panduan Akademik terbaru Universitas Bengkulu untuk Program Sarjana dan Diploma:\n\n- Panduan Akademik Tahun 2024 - laman web:https://drive.google.com/file/d/15ovt1yb0LAY38DK5JyNu0EBqnq5y4S4p/view"
       ]
    },
    {
       "tag": "goodbye",
            "patterns": ["Terima kasih", "selesai", "oke", "thankyou", "stop", "ok", "bye"],
            "responses": [
            "Terima kasih telah berbincang dengan sahabatunib. Sampai jumpa! 😊", "Semoga harimu menyenankan! Sampai jumpa!", "Terima kasih sudah bertanya, semoga bermanfaat! 😊"
       ]
    }
  ]
}

  # Simpan ke dalam file JSON
with open('chatbot_InformasiUNIB.json', 'w') as json_file:
    json.dump(data, json_file, indent=4)
